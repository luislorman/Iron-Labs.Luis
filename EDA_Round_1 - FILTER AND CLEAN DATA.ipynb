# %%
import pandas as pd
import numpy as np

# %%
#FILE 1
Acase_df= pd.read_csv("Data-Customer_analysis_case/file1.csv")
Acase_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#FILE 2 import file2

Bcase_df= pd.read_csv(r"Data-Customer_analysis_case/file2.csv")
Bcase_df
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
#FILE 3 ## import file 3

Ccase_df= pd.read_csv("Data-Customer_analysis_case/file3.csv")
Ccase_df
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
  ## lower head
    
def lower_case_column_names(Ccase_df):
    Ccase_df.columns=[i.lower() for i in Ccase_df.columns]
    return Ccase_df


Ccase_df=lower_case_column_names(Ccase_df)



    
def AAAAAAAAAA(Acase_df):
    Acase_df.columns=[i.lower() for i in Acase_df.columns]
    return Acase_df


Acase_df=lower_case_column_names(Acase_df)
    
def lower_case_column_names(Bcase_df):
    Bcase_df.columns=[i.lower() for i in Bcase_df.columns]
    return Bcase_df


Bcase_df=lower_case_column_names(Bcase_df)
Bcase_df
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
#head

Acase_df.columns.unique()
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
Bcase_df.columns.unique()
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
Ccase_df.columns.unique()
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
Ccase_df
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
#rename A and B

Bcase_df.rename(columns={"st": "state"}, inplace=True) # rename column st from file file2 y asignar un nuevo valor
Acase_df.rename(columns={"st": "state"}, inplace=True)
Acase_df       ### si no add inplace, tengo que crear una nueva variable es decir AAcase=Acase_df.rename(columns={"st": "state"})
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# reordenate columns of all files in the same order before concatenation           

Bcase_df.loc[:, ['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'total claim amount', 'policy type', 'vehicle class']]
# Out:
#     customer       state gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
Acase_df.drop_duplicates()  # drop duplicates 
Bcase_df.drop_duplicates()
Ccase_df.drop_duplicates()
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
#concatenar of thre files

cars_data = pd.concat([Acase_df,Bcase_df,Ccase_df], axis=0)
cars_data.reset_index(inplace=True, drop=True) #hay q resetear si no habra 2 indexs, el viejo y uno nuevo

# %%
cars_data= cars_data.drop("customer",inplace=False, axis=1)

# %%
cars_data
# Out:
#             state gender             education customer lifetime value  \
# 0      Washington    NaN                Master                     NaN
# 1         Arizona      F              Bachelor              697953.59%
# 2          Nevada      F              Bachelor             1288743.17%
# 3      California      M              Bachelor              764586.18%
# 4      Washington      M  High School or Below              536307.65%
# ...           ...    ...                   ...                     ...
# 12069  California      M              Bachelor             23405.98798
# 12070  California      F               College             3096.511217
# 12071  California      M              Bachelor             8163.890428
# 12072  California      M               College             7524.442436
# 12073  California      M               College             2611.836866
#
#         income  monthly premium auto number of open complaints  \
# ...

# %%
cars_data.info()  ## customer lifetime value  - number of open complaints from object to int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      9137 non-null   object
#  1   gender                     9015 non-null   object
#  2   education                  9137 non-null   object
#  3   customer lifetime value    9130 non-null   object
#  4   income                     9137 non-null   float64
#  5   monthly premium auto       9137 non-null   float64
#  6   number of open complaints  9137 non-null   object
#  7   policy type                9137 non-null   object
#  8   vehicle class              9137 non-null   object
#  9   total claim amount         9137 non-null   float64
# dtypes: float64(3), object(7)
# memory usage: 943.4+ KB

# %%
new_cars_data= cars_data  # nueva variable para el data frame

# %%
new_cars_data["customer lifetime value"] = cars_data["customer lifetime value"].apply(lambda x: float(x.rstrip("%")) / 100.0  if isinstance(x,str) else x) # quitar %
new_cars_data["number of open complaints"] = new_cars_data["number of open complaints"].apply(lambda x: str(x).split("/")[1] if len(str(x).split("/")) >1 else x) #quito los porcentajes y se anhade un 0 extra al 7 para indexzalo y luego quitarlo mas facilmenete

# %%
 #pasar a int este columna en objeto clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.

# %%
new_cars_data['customer lifetime value'] =  pd.to_numeric(new_cars_data['customer lifetime value'], errors='coerce')  # quita los an
new_cars_data['number of open complaints'] =  pd.to_numeric(new_cars_data['number of open complaints'], errors='coerce')
new_cars_data  #### la tabal s eve igual, XQ?
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
#removing na= to missing data
new_cars_data.dropna()
new_cars_data
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
#### STANDARIZE COLUMNS STATE AND GENDER

new_cars_data.state.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
test=new_cars_data ####  security copy
new_test=cars_data
new_test
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
#cleaning column STATES  and GENDER
#THIS FORMULA DOESNT WORK
#new_list=()
#for i in test["state"]:
    #if i["WA"]:
        #new_list.append('Washington')
    #elif i["AZ"]:
        #new_list.append('Arizona')
    #elif i["Cali"]:
        #new_list.append('California')
    #elif np.nan:  pass  # nan significa no data; NULL, misisng data
    #else:
        #new_list.append("U") 
        
 #######


new_cars_data["state"] = new_cars_data["state"].replace({"Cali": "California","AZ" :"Arizona","WA":"Washington"})

# %%
#removing again nan= to missing data
new_cars_data.dropna()
new_cars_data
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
new_cars_data["state"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan],
#       dtype=object)

# %%
test=new_cars_data
test
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
###### TUESDAY new_cars_data MISSING REMOVING THE 0 !!!!!!!!

# %%
test #test=new_cars_data
# Out:
#             state gender             education  customer lifetime value  \
# 0      Washington    NaN                Master                      NaN
# 1         Arizona      F              Bachelor              6979.535900
# 2          Nevada      F              Bachelor             12887.431700
# 3      California      M              Bachelor              7645.861800
# 4      Washington      M  High School or Below              5363.076500
# ...           ...    ...                   ...                      ...
# 12069  California      M              Bachelor             23405.987980
# 12070  California      F               College              3096.511217
# 12071  California      M              Bachelor              8163.890428
# 12072  California      M               College              7524.442436
# 12073  California      M               College              2611.836866
#
#         income  monthly premium auto  number of open complaints  \
# ...

# %%
#- Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values)
#Hint: numpy.nan is considered of float64 data type.

#test.loc[test["customer lifetime value"] == 0, "customer lifetime value"] = None
#test.loc[test["income"] == 0, "income"] = None
#test.loc[test[["monthly premium auto"] == 0, ["monthly premium auto"] = None
#test.loc[test["total claim amount"] == 0,["total claim amount"] = None

test["customer lifetime value"] = test["customer lifetime value"].astype(float)
test["income"] = test["income"].astype(float)
test["monthly premium auto"] = test["monthly premium auto"].astype(float)
test["total claim amount"] = test["total claim amount"].astype(float)

atest = test["customer lifetime value"].mean()
btest = test["income"].mean()
ctest = test["monthly premium auto"].mean()
dtest = test["total claim amount"].mean()

#cars_data_filtered[‘Customer Lifetime Value’] = cars_data_filtered[‘Customer Lifetime Value’].fillna(value=cars_data_filtered[‘Customer Lifetime Value’].mean())
#cars_data_filtered[‘Income’] = cars_data_filtered[‘Income’].fillna(value=cars_data_filtered[‘Income’].mean())
#cars_data_filtered[‘Monthly Premium Auto’] = cars_data_filtered[‘Monthly Premium Auto’].fillna(value=cars_data_filtered[‘Monthly Premium Auto’].mean())
#cars_data_filtered[‘Total Claim Amount’] = cars_data_filtered[‘Total Claim Amount’].fillna(value=cars_data_filtered[‘Total Claim Amount’].mean())
# Out:
# 7977.0577040724975

# %%
new_test=test

new_test["customer lifetime value"] = new_test["customer lifetime value"].replace({"0.000000":atest})

new_test.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              9130.000000   9137.000000           9137.000000
# mean               7977.057704  37828.820291            110.391266
# std                6809.350707  30358.716159            581.376032
# min                1898.007675      0.000000             61.000000
# 25%                3980.525782      0.000000             68.000000
# 50%                5764.716400  34244.000000             83.000000
# 75%                8931.773240  62447.000000            109.000000
# max               83325.381190  99981.000000          35354.000000
#
#        number of open complaints  total claim amount
# count                9137.000000         9137.000000
# mean                    0.383715          430.527140
# std                     0.908988          289.582968
# min                     0.000000            0.099007
# 25%                     0.000000          266.996814
# ...

# %%
#remove value 0 beacause is == to null

new_test=test


new_test.drop(new_test[new_test['income'] == 0].index)

# %%
#Bucketing the data - Write a function to replace column "State"
#to different zones. California as West Region, Oregon as North West,
#and Washington as East, and Arizona and Nevada as Central


test["state"] = test["state"].replace({"California": "West Region","Oregon" :"North West","Washington":"East", "Arizona":"Central", "Nevada":"central"})

# %%
new_test=test

news_test= new_test.rename(columns={"state": "different zones"})


new_test
