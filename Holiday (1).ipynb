# %% [markdown]
# # 1. Dream holiday destination for a friend -
# Task description: In the notebook that you created, you will introduce someone and her/his holidays preference with a picture and a link to a youtube video of this holiday preference (It can be you, a friend or family member :D)

# %% [markdown]
# ##  2. Who wants to visit Hawaii?

# %%
fname = input ("Please introduce friend's name ")
print ("Your friend's name is","",fname)
# Out:
# Please introduce friend's name Pepe
# Your friend's name is  Pepe

# %% [markdown]
# ![dude.jpg](attachment:dude.jpg)

# %% [markdown]
# ###  *2.1 Holiday destination --> Hawaii !!*

# %% [markdown]
# ![hawaii.jpg](attachment:hawaii.jpg)

# %% [markdown]
# **2.2 Key activities:**
#
# - Hiking
# - Diving
# - National food

# %% [markdown]
#  [Promotional video](https://www.youtube.com/watch?v=wZuQhoDHvdM)

# %% [markdown]
# ### 3. Notes
#
# **Used functions:**
#  -  fname = input ("Please introduce your name")
#      print ("Your name is", fname)
#  -  [titel name}(web-link)"
